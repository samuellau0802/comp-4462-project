# %%
country_currency = {
    "Fiji": "FJD",
    "Tanzania": "TZS",
    "W. Sahara": "SHP",
    "Canada": "CAD",
    "United States of America": "USD",
    "Kazakhstan": "KZT",
    "Uzbekistan": "UZS",
    "Papua New Guinea": "PGK",
    "Indonesia": "IDR",
    "Argentina": "ARS",
    "Chile": "CLP",
    "Dem. Rep. Congo": "CDF",
    "Somalia": "SOS",
    "Kenya": "KES",
    "Sudan": "SDG",
    "Chad": "XAF",
    "Haiti": "HTG",
    "Dominican Rep.": "DOP",
    "Russia": "RUB",
    "Bahamas": "BSD",
    "Falkland Is.": "FKP",
    "Norway": "NOK",
    "Greenland": "DKK",
    "Timor-Leste": "USD",
    "Central African Rep.": "ZAR",
    "Lesotho": "LSL",
    "Mexico": "MXN",
    "Uruguay": "UYU",
    "Brazil": "BRL",
    "Bolivia": "BOB",
    "Peru": "PEN",
    "Colombia": "COP",
    "Panama": "PAB",
    "Costa Rica": "CRC",
    "Nicaragua": "NIO",
    "Honduras": "HNL",
    "El Salvador": "USD",
    "Guatemala": "GTQ",
    "Belize": "BZD",
    "Venezuela": "VES",
    "Guyana": "GYD",
    "Suriname": "SRD",
    "France": "EUR",
    "Ecuador": "USD",
    "Puerto Rico": "USD",
    "Jamaica": "JMD",
    "Cuba": "CUP",
    "Zimbabwe": "USD",
    "Botswana": "BWP",
    "Namibia": "NAD",
    "Senegal": "XOF",
    "Mali": "XOF",
    "Mauritania": "MRU",
    "Benin": "XOF",
    "Niger": "XOF",
    "Nigeria": "NGN",
    "Cameroon": "XAF",
    "Togo": "XOF",
    "Ghana": "GHS",
    "Côte d'Ivoire": "XOF",
    "Guinea": "GNF",
    "Liberia": "LRD",
    "Sierra Leone": "SLL",
    "Burkina Faso": "XOF",
    "CAR": "XAF",
    "Congo": "XAF",
    "Gabon": "XAF",
    "Eq. Guinea": "XAF",
    "Zambia": "ZMW",
    "Malawi": "MWK",
    "Mozambique": "MZN",
    "eSwatini": "SZL",
    "Angola": "AOA",
    "Burundi": "BIF",
    "Israel": "ILS",
    "Lebanon": "LBP",
    "Madagascar": "MGA",
    "Palestine": "ILS",
    "Gambia": "GMD",
    "Tunisia": "TND",
    "Algeria": "DZD",
    "Jordan": "JOD",
    "UAE": "AED",
    "Qatar": "QAR",
    "Kuwait": "KWD",
    "Iraq": "IQD",
    "Oman": "OMR",
    "Vanuatu": "VUV",
    "Cambodia": "KHR",
    "Thailand": "THB",
    "Laos": "LAK",
    "Myanmar": "MMK",
    "Vietnam": "VND",
    "N. Korea": "KPW",
    "S. Korea": "KRW",
    "Mongolia": "MNT",
    "India": "INR",
    "Bangladesh": "BDT",
    "Bhutan": "BTN",
    "Nepal": "NPR",
    "Pakistan": "PKR",
    "Afghanistan": "AFN",
    "Tajikistan": "TJS",
    "Kyrgyzstan": "KGS",
    "Turkmenistan": "TMT",
    "Iran": "IRR",
    "Syria": "SYP",
    "Armenia": "AMD",
    "Sweden": "SEK",
    "Belarus": "BYN",
    "Ukraine": "UAH",
    "Poland": "PLN",
    "Austria": "EUR",
    "Hungary": "HUF",
    "Moldova": "MDL",
    "Romania": "RON",
    "Lithuania": "EUR",
    "Latvia": "EUR",
    "Estonia": "EUR",
    "Germany": "EUR",
    "Bulgaria": "BGN",
    "Greece": "EUR",
    "Turkey": "TRY",
    "Albania": "ALL",
    "Croatia": "HRK",
    "Switzerland": "CHF",
    "Luxembourg": "EUR",
    "Belgium": "EUR",
    "Netherlands": "EUR",
    "Portugal": "EUR",
    "Spain": "EUR",
    "Ireland": "EUR",
    "New Caledonia": "XPF",
    "Solomon Is.": "AUD",
    "New Zealand": "NZD",
    "Australia": "AUD",
    "Sri Lanka": "LKR",
    "China": "CNY",
    "Taiwan": "TWD",
    "Italy": "EUR",
    "Denmark": "DKK",
    "United Kingdom": "GBP",
    "Iceland": "ISK",
    "Azerbaijan": "AZN",
    "Georgia": "GEL",
    "Philippines": "PHP",
    "Malaysia": "MYR",
    "Brunei": "BND",
    "Slovenia": "EUR",
    "Finland": "EUR",
    "Slovakia": "EUR",
    "Czechia": "CZK",
    "Eritrea": "ERN",
    "Japan": "JPY",
    "Paraguay": "PYG",
    "Yemen": "YER",
    "Saudi Arabia": "SAR",
    "Antarctica": "N/A",
    "N. Cyprus": "TRY",
    "Cyprus": "EUR",
    "Morocco": "MAD",
    "Egypt": "EGP",
    "Libya": "LYD",
    "Ethiopia": "ETB",
    "Djibouti": "DJF",
    "Somaliland": "SOS",
    "Uganda": "UGX",
    "Rwanda": "RWF",
    "Bosnia and Herz.": "BAM",
    "Macedonia": "MKD",
    "Serbia": "RSD",
    "Montenegro": "EUR",
    "Kosovo": "EUR",
    "Trinidad and Tobago": "TTD",
    "S. Sudan": "SSP"
}

# %%
import json

with open("countries_data_2008_2023.json", "r") as f:
    data = json.load(f)

# %%
# Combine the two structures
combined_data = {}
for country, currency in country_currency.items():
    if country in data:
        combined_data[country] = {
            "Currency": currency,
            "Economic Data": data[country]
        }

# %%
combined_data
# Out:
# {'Fiji': {'Currency': 'FJD',
#   'Economic Data': {'2008': {'Inflation': 7.732278579,
#     'Index Price': 'NaN',
#     'Unemployment Rate': 4.182,
#     'Balance of Trade': -526301838.9,
#     'Government Debt-to-GDP': 'NaN',
#     'FX Reserves': 322181205.0,
#     'GDP growth (annual %)': 1.03279422},
#    '2009': {'Inflation': 3.13103559,
#     'Index Price': 'NaN',
#     'Unemployment Rate': 4.302,
#     'Balance of Trade': -123989445.2,
#     'Government Debt-to-GDP': 'NaN',
#     'FX Reserves': 570005077.9,
#     'GDP growth (annual %)': -1.386037708},
#    '2010': {'Inflation': 3.689012297,
#     'Index Price': 'NaN',
#     'Unemployment Rate': 4.342,
#     'Balance of Trade': -149446716.1,
#     'Government Debt-to-GDP': 'NaN',
#     'FX Reserves': 720523356.8,
#     'GDP growth (annual %)': 2.954672422},
#    '2011': {'Inflation': 7.278117827,
#     'Index Price': 'NaN',
#     'Unemployment Rate': 4.406,
#     'Balance of Trade': -195062701.8,
# ...

# %%
from currency_converter import CurrencyConverter

# Initialize the CurrencyConverter
c = CurrencyConverter()

# Convert FX reserves from USD to the country's currency
for country, details in combined_data.items():
    currency = details['Currency']
    for year, economic_data in details['Economic Data'].items():
        if 'FX Reserves' in economic_data and economic_data['FX Reserves'] != 'NaN':
            try:
                economic_data['FX Reserves'] = c.convert(economic_data['FX Reserves'], 'USD', currency)
            except:
                pass
                # PyCurrency_Converter.convert(economic_data['FX Reserves'], 'USD', currency)
# print(combined_data)

# %%
with open("src/data/countries_data_2008_2023.json", "w") as f:
    json.dump(combined_data, f, indent=4)
